# %% [markdown]
# <a href="https://colab.research.google.com/github/saransh437/Feature_engineering/blob/main/feature_eng_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Raw Data
#    ↓
# Understand Problem -> Understand the Problem & Data <> Business goal? <> target column
#    ↓
# EDA -> Understand data behavior. <> missing values <> Outliers
#    ↓
# Cleaning -> handle missing value , duplicate , incorrect values, handle outliers , split data
#    ↓
# Transformations -> scaling , normalization , encoding categorical data
#    ↓
# Feature Creation -> Create new useful features from existing data
#    ↓
# Feature Selection -> Remove useless or harmful features. , Reduce overfitting ,Better generalization
#    ↓
# Scaling -> Make features comparable. and Never use future information.
#    ↓
# Validation -> Check if features actually help.
#    ↓
# Pipeline -> automate processing
#    ↓
# Model Training

# %%
# Split the data immediately after basic cleaning and BEFORE feature engineering that learns from data. which prevent data leakage
# problem -> Test data information leaks into training. model will give high accuracy

# %%
# machine learning ->
# data(50) ---> x(input data), y(target data)
# x---> x_train , x_test
# y ---> y_train , y_test
# for machine learning training we pass x_train and y_train then it learn and recognise pattern from it
# for ml testing -> (x_test) ---> y_pred
